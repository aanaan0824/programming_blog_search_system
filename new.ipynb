# %%
import requests

resp= requests.get("https://blog.csdn.net/benzhujie1245com/article/details/117089767", headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0",
    #"Cookie":"log_Id_pv=715; uuid_tt_dd=10_30815930450-1631606403588-112982; log_Id_view=2629; Hm_lvt_6bcd52f51e9b3dce32bec4a3997715ac=1660023423; Hm_up_6bcd52f51e9b3dce32bec4a3997715ac=%7B%22islogin%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22isonline%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22isvip%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22uid_%22%3A%7B%22value%22%3A%22m0_60897957%22%2C%22scope%22%3A1%7D%7D; Hm_ct_6bcd52f51e9b3dce32bec4a3997715ac=6525*1*10_30815930450-1631606403588-112982!5744*1*m0_60897957; __gads=ID=79f4050fafc4d350-226c3361a2cb0048:T=1631606636:RT=1631606636:S=ALNI_MZW5MBbckOmSzJogMbF9rfxXK1fxA; log_Id_click=437; UN=m0_60897957; BT=1654090771391; ssxmod_itna=eq0xgDRDnD0DyGDc0DzEKnx0I7ulWQn7DIowG34GXxP3DZDiqAPGhDC+8FhAR0huGxfI7faqa+7ASRRYYFUmDnQWDCPGnDBKoeWixYAkDt4DTD34DYDixib8xi5GRD0KDFbVztZcDm4i3ExDbDiW8wxGCDeKD0PqFDQKDupKh7hACi45oe3W8D7vmDlae+Ri8Qt8EQlv3wx0kX40OnoHz8xoDU0IzcZ5PdAR4H6PDmZ3Dyrg=Dia8q0iUQD0tEppF8AicDGH9WW23qibxKnDozyDxrC/SK74o3P2xNBiaaCNDi=iZaQGDD==; ssxmod_itna2=eq0xgDRDnD0DyGDc0DzEKnx0I7ulWQn7DIowDA=Weq5D/QYDFOGWrIZPhrzzua4=zqzaT9=+UIr+IKH80rMPux=12CATfbxbwMjj0mr6BjYC=ClM7Lyi0Z1a+ADQKqHDFqG7QeD=; __gpi=UID=0000058ddabffc66:T=1652947691:RT=1661915179:S=ALNI_MZSLyYxJeCTGxyDV8IJ_1REz6BOsA; _ga=GA1.2.1103603590.1653901421; UserName=m0_60897957; UserInfo=74d6c6c3921446faaae7185080c4d866; UserToken=74d6c6c3921446faaae7185080c4d866; UserNick=m0_60897957; AU=A11; p_uid=U110000; c_dl_prid=1660738219924_624386; c_dl_rid=1660738227694_849081; c_dl_fref=https://bbs.csdn.net/topics/396276468; c_dl_fpage=/download/buffaloiron/1898688; c_dl_um=-; historyList-new=%5B%22python%E7%88%AC%E8%99%AB%22%5D; c_pref=https%3A//blog.csdn.net/nav/lang; c_ref=https%3A//www.baidu.com/link; c_first_ref=www.baidu.com; c_first_page=https%3A//blog.csdn.net/crack6677/article/details/105346486; c_segment=6; Hm_lpvt_6bcd52f51e9b3dce32bec4a3997715ac=1661915142; dc_sid=aaf104ee112f3011cb33ca6d0922c856; SESSION=fe4b6696-0cc1-4808-8889-400605bdfb09; x_dev_cloud_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjcmVkZW50aWFsIjoiIiwiY3NkblVzZXJuYW1lIjoibTBfNjA4OTc5NTciLCJ1c2VySWQiOiI2MmY5ZTgzNTQ2ZDY3ZTIwMDk0ZWNhNTUiLCJ1c2VybmFtZSI6Im0wXzYwODk3OTU3In0.pbgV0w69VSwxPQDvWum3GS8SxKbL_KSGSJSQcFFbNeo; firstDie=1; csdn_highschool_close=close; dc_session_id=10_1661914052967.456441; c_dsid=11_1661915140821.234685; dc_tos=rhglxo; c_page_id=default; FCNEC=[[\"AKsRol9zS0zJ15IChGCLG_k0AxgM7e3fJiVW29kUTRnjLn81NPCJURscX6HdYEszz5gn7aA3yWdOvo8CW8Se7NpvFAnymcA4TIWDwnUJsqduIyVkBepqxQYfKuP3PWNwRVCOSooxMsQzYYuEOBaBrRQ88RFBwiK5yQ==\"],null,[]]"
})

# %%
resp
# Out:
# <Response [200]>

# %%
f=open("try.html","wb")
f.write(resp.content)
# Out:
# 226389

# %%
from bs4 import BeautifulSoup as BS

# %%
soup = BS(resp.content)

# %%
divs=soup.find_all('div',class_="active-blog")
f=open("try.txt","w")
for i in divs:
    tmp=i.find('a')['href']
    f.write(tmp)
    f.write("\n")
    #print(tmp)
f.close()

# %%
from selenium import webdriver

# %%
from selenium.webdriver.remote.webdriver import WebDriver as wd
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait as wdw
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains as AC
import selenium
from bs4 import BeautifulSoup as BS
import json

# %%
chrome_options = selenium.webdriver.chrome.options.Options()
chrome_options.page_load_strategy='eager'

d = selenium.webdriver.Chrome(options=chrome_options)

# %%
d.get("https://blog.csdn.net")
f=open("try.txt","a")
for i in range(1,30):
    soup1=BS(d.page_source)
    divs=soup1.find_all('div',class_="active-blog")
    for i in divs:
        tmp=i.find('a')['href']
        f.write(tmp)
        f.write("\n")
        #print(tmp)
    d.refresh()
    d.implicitly_wait(0.5)
f.close()

# %%
soup1=BS(d.page_source)

# %%
divs=soup1.find_all('div',class_="active-blog")
f=open("try.txt","w")
for i in divs:
    tmp=i.find('a')['href']
    f.write(tmp)
    f.write("\n")
    #print(tmp)
f.close()

# %%
with open("try.txt","r") as lines:
    for line in lines:
        resp1= requests.get(line, headers={
            "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0",
            #"Cookie":"log_Id_pv=715; uuid_tt_dd=10_30815930450-1631606403588-112982; log_Id_view=2629; Hm_lvt_6bcd52f51e9b3dce32bec4a3997715ac=1660023423; Hm_up_6bcd52f51e9b3dce32bec4a3997715ac=%7B%22islogin%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22isonline%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22isvip%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22uid_%22%3A%7B%22value%22%3A%22m0_60897957%22%2C%22scope%22%3A1%7D%7D; Hm_ct_6bcd52f51e9b3dce32bec4a3997715ac=6525*1*10_30815930450-1631606403588-112982!5744*1*m0_60897957; __gads=ID=79f4050fafc4d350-226c3361a2cb0048:T=1631606636:RT=1631606636:S=ALNI_MZW5MBbckOmSzJogMbF9rfxXK1fxA; log_Id_click=437; UN=m0_60897957; BT=1654090771391; ssxmod_itna=eq0xgDRDnD0DyGDc0DzEKnx0I7ulWQn7DIowG34GXxP3DZDiqAPGhDC+8FhAR0huGxfI7faqa+7ASRRYYFUmDnQWDCPGnDBKoeWixYAkDt4DTD34DYDixib8xi5GRD0KDFbVztZcDm4i3ExDbDiW8wxGCDeKD0PqFDQKDupKh7hACi45oe3W8D7vmDlae+Ri8Qt8EQlv3wx0kX40OnoHz8xoDU0IzcZ5PdAR4H6PDmZ3Dyrg=Dia8q0iUQD0tEppF8AicDGH9WW23qibxKnDozyDxrC/SK74o3P2xNBiaaCNDi=iZaQGDD==; ssxmod_itna2=eq0xgDRDnD0DyGDc0DzEKnx0I7ulWQn7DIowDA=Weq5D/QYDFOGWrIZPhrzzua4=zqzaT9=+UIr+IKH80rMPux=12CATfbxbwMjj0mr6BjYC=ClM7Lyi0Z1a+ADQKqHDFqG7QeD=; __gpi=UID=0000058ddabffc66:T=1652947691:RT=1661915179:S=ALNI_MZSLyYxJeCTGxyDV8IJ_1REz6BOsA; _ga=GA1.2.1103603590.1653901421; UserName=m0_60897957; UserInfo=74d6c6c3921446faaae7185080c4d866; UserToken=74d6c6c3921446faaae7185080c4d866; UserNick=m0_60897957; AU=A11; p_uid=U110000; c_dl_prid=1660738219924_624386; c_dl_rid=1660738227694_849081; c_dl_fref=https://bbs.csdn.net/topics/396276468; c_dl_fpage=/download/buffaloiron/1898688; c_dl_um=-; historyList-new=%5B%22python%E7%88%AC%E8%99%AB%22%5D; c_pref=https%3A//blog.csdn.net/nav/lang; c_ref=https%3A//www.baidu.com/link; c_first_ref=www.baidu.com; c_first_page=https%3A//blog.csdn.net/crack6677/article/details/105346486; c_segment=6; Hm_lpvt_6bcd52f51e9b3dce32bec4a3997715ac=1661915142; dc_sid=aaf104ee112f3011cb33ca6d0922c856; SESSION=fe4b6696-0cc1-4808-8889-400605bdfb09; x_dev_cloud_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjcmVkZW50aWFsIjoiIiwiY3NkblVzZXJuYW1lIjoibTBfNjA4OTc5NTciLCJ1c2VySWQiOiI2MmY5ZTgzNTQ2ZDY3ZTIwMDk0ZWNhNTUiLCJ1c2VybmFtZSI6Im0wXzYwODk3OTU3In0.pbgV0w69VSwxPQDvWum3GS8SxKbL_KSGSJSQcFFbNeo; firstDie=1; csdn_highschool_close=close; dc_session_id=10_1661914052967.456441; c_dsid=11_1661915140821.234685; dc_tos=rhglxo; c_page_id=default; FCNEC=[[\"AKsRol9zS0zJ15IChGCLG_k0AxgM7e3fJiVW29kUTRnjLn81NPCJURscX6HdYEszz5gn7aA3yWdOvo8CW8Se7NpvFAnymcA4TIWDwnUJsqduIyVkBepqxQYfKuP3PWNwRVCOSooxMsQzYYuEOBaBrRQ88RFBwiK5yQ==\"],null,[]]"
        })
        sp1=BS(resp1)
        div_writers=sp1.find_all("div",id_="asideProfile")

# %%
import re
import json
import requests
from bs4 import BeautifulSoup as BS

def dealWebsite(website : str):
    #print(website,"https://blog.csdn.net/weixin_54696666/article/details/126603219")
    #print(website=="https://blog.csdn.net/weixin_54696666/article/details/126603219")
    #print(len(website),len("https://blog.csdn.net/weixin_54696666/article/details/126603219"))
    blogid=website.split('/')[-1]

    resp1= requests.get(website, headers={
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0",
        #"Cookie":"log_Id_pv=817; uuid_tt_dd=10_30815930450-1631606403588-112982; log_Id_view=3040; Hm_lvt_6bcd52f51e9b3dce32bec4a3997715ac=1660023423; Hm_up_6bcd52f51e9b3dce32bec4a3997715ac=%7B%22islogin%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22isonline%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22isvip%22%3A%7B%22value%22%3A%221%22%2C%22scope%22%3A1%7D%2C%22uid_%22%3A%7B%22value%22%3A%22m0_60897957%22%2C%22scope%22%3A1%7D%7D; Hm_ct_6bcd52f51e9b3dce32bec4a3997715ac=6525*1*10_30815930450-1631606403588-112982!5744*1*m0_60897957; __gads=ID=79f4050fafc4d350-226c3361a2cb0048:T=1631606636:RT=1631606636:S=ALNI_MZW5MBbckOmSzJogMbF9rfxXK1fxA; log_Id_click=546; UN=m0_60897957; BT=1654090771391; Hm_lvt_e5ef47b9f471504959267fd614d579cd=1661919860; ssxmod_itna=eq0xgDRDnD0DyGDc0DzEKnx0I7ulWQn7DIowG34GXxP3DZDiqAPGhDC+8FhAR0huGxfI7faqa+7ASRRYYFUmDnQWDCPGnDBKoeWixYAkDt4DTD34DYDixib8xi5GRD0KDFbVztZcDm4i3ExDbDiW8wxGCDeKD0PqFDQKDupKh7hACi45oe3W8D7vmDlae+Ri8Qt8EQlv3wx0kX40OnoHz8xoDU0IzcZ5PdAR4H6PDmZ3Dyrg=Dia8q0iUQD0tEppF8AicDGH9WW23qibxKnDozyDxrC/SK74o3P2xNBiaaCNDi=iZaQGDD==; ssxmod_itna2=eq0xgDRDnD0DyGDc0DzEKnx0I7ulWQn7DIowDA=Weq5D/QYDFOGWrIZPhrzzua4=zqzaT9=+UIr+IKH80rMPux=12CATfbxbwMjj0mr6BjYC=ClM7Lyi0Z1a+ADQKqHDFqG7QeD=; __gpi=UID=0000058ddabffc66:T=1652947691:RT=1662050358:S=ALNI_MZSLyYxJeCTGxyDV8IJ_1REz6BOsA; _ga=GA1.2.1103603590.1653901421; UserName=m0_60897957; UserInfo=74d6c6c3921446faaae7185080c4d866; UserToken=74d6c6c3921446faaae7185080c4d866; UserNick=m0_60897957; AU=A11; p_uid=U110000; c_dl_prid=1660738227694_849081; c_dl_rid=1662051908632_238895; c_dl_fref=https://so.csdn.net/so/search; c_dl_fpage=/download/weixin_38639237/13766436; c_dl_um=distribute.pc_search_result.none-task-blog-2%7Eall%7Etop_positive%7Edefault-2-119912882-null-null.142%5Ev44%5Epc_rank_34_default_23; historyList-new=%5B%22dictionary%20%E8%BD%AC%E5%8C%96%E4%B8%BA%20json%20python%22%2C%22python%20json%20dictionary%22%2C%22python%20json%22%2C%22python%20%E5%82%A8%E5%AD%98%E6%95%B0%E6%8D%AE%E5%88%B0json%22%2C%22C%2B%2B%22%2C%22python%E7%88%AC%E8%99%AB%22%5D; csdn_highschool_close=close; cms_blog_nav_flag=true; c_pref=default; c_ref=default; c_first_ref=default; c_first_page=https%3A//blog.csdn.net/weixin_54696666/article/details/126603219; c_segment=6; Hm_lpvt_6bcd52f51e9b3dce32bec4a3997715ac=1662086441; dc_sid=aaf104ee112f3011cb33ca6d0922c856; SESSION=fe4b6696-0cc1-4808-8889-400605bdfb09; x_dev_cloud_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjcmVkZW50aWFsIjoiIiwiY3NkblVzZXJuYW1lIjoibTBfNjA4OTc5NTciLCJ1c2VySWQiOiI2MmY5ZTgzNTQ2ZDY3ZTIwMDk0ZWNhNTUiLCJ1c2VybmFtZSI6Im0wXzYwODk3OTU3In0.pbgV0w69VSwxPQDvWum3GS8SxKbL_KSGSJSQcFFbNeo; csrfToken=BSRO_7n7e533GISHsdVElWaf; cms_blog_nav={%22cate1%22:%22web%22%2C%22cate2%22:{%22type%22:%22javascript%22%2C%22title%22:%22javascript%22}}; Hm_lpvt_e5ef47b9f471504959267fd614d579cd=1661919872; firstDie=1; FCNEC=[["AKsRol_74C20jgrfNJoirUZ55jg24hf8LTHCLZV_PO2rL-LE1SHXbIC5T5hrORsMzkxOd21HICKAwFc8ntpdRtevIh288gguMWE_WwEP3IjMocG2ndStnfljcgkyRUwCT2876Fk0DapNllEVplBqig29Gq1YVs9tVA=="],null,[]]; dc_session_id=10_1662086377233.161962; c_dsid=11_1662086441212.897845; dc_tos=rhka3t; c_page_id=default"
    })
    sp1=BS(resp1.content)
    #print(resp1)
    div_writers=sp1.find("div",id="asideProfile")
    if(div_writers==None):
        return
    #print("hihihihi")
    #print(div_writers)
    #print(sp1.contents)

    #get the writer info

    writerPicsURL=div_writers.find('img',class_="avatar_pic").get("src")
    writerimagename='profile_'+blogid+'.jpg'
    profile_writer=requests.get(writerPicsURL,headers={
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0"
    })
    with open(str("writer_image"+"\\"+writerimagename),"wb") as fprofile:
        fprofile.write(profile_writer.content)
    
    writerName=div_writers.find('a',id="uid",class_="",target="_blank").get("title")
    if(div_writers.find('span',class_="personal-home-page personal-home-years")!=None):
        writerAge=div_writers.find('span',class_="personal-home-page personal-home-years").string
    else:
        writerAge="None"
    text_centers=div_writers.find_all('dl',class_="text-center")
    writerBlogNum=text_centers[0].get("title")
    writerRankWeekly=text_centers[1].get("title")
    writerRankTotal=text_centers[2].get("title")
    writerVisitNum=text_centers[3].get("title")
    writerGrade=text_centers[4].get("title").split(',')[0]
    writerIntegral=text_centers[5].get("title")
    writerFan=text_centers[6].get("title")
    writerThumb=text_centers[7].get("title")
    writerComment=text_centers[8].get("title")
    writerCollect=text_centers[9].get("title")

    #get the title

    blog_title=sp1.find("h1",id="articleContentId",class_="title-article").string
    blog_time=sp1.find("span",class_="time").string
    blog_read_count=sp1.find("span",class_="read-count").string

    #get the content

    content=sp1.find('article',class_="baidu_pl")
    content.find('link',rel="stylesheet")['href']="style.css"
    images=content.find_all('img')
    #print(images)
    for image in images:
        srcsite=image.get("src")
        if(srcsite==''):
            continue
        #print(srcsite)
        try:
            imagenames=srcsite.split('/')
            imageself=requests.get(srcsite,headers={
                "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0"
            })
            for thing in imagenames:
                if re.match('.*\.png',thing):
                    imagename=re.match('.*\.png',thing).group()
                    #print(type(imagename))
                    #re.sub('.*\.png',imagename,thing)
                    image["src"]=str("image"+"\\"+imagename)
                    with open(str("image"+"\\"+imagename),"wb") as fimage:
                        fimage.write(imageself.content)
                    break
                if re.match('.*\.jpg',thing):
                    imagename=re.match('.*\.jpg',thing).group()
                    #re.sub('.*\.png',imagename,thing)
                    image["src"]=str("image"+"\\"+imagename)
                    with open(str("image\\"+imagename),"wb") as fimage:
                        fimage.write(imageself.content)
                    break
                if re.match('.*\.jpeg',thing):
                    imagename=re.match('.*\.jpeg',thing).group()
                    #re.sub('.*\.png',imagename,thing)
                    image["src"]=str("image"+"\\"+imagename)
                    with open(str("image\\"+imagename),"wb") as fimage:
                        fimage.write(imageself.content)
                    break
        except:
            continue
    #with open("trytry.html","w") as trytryf:
        #trytryf.write(str(content.contents[1]))
    
    #encoding to json

    string_tmp=str(content.contents[1]).replace(u'\xa0', u' ')
    data={
        "blogid":blogid,
        "writerAge":writerAge,
        "writerBlogNum":writerBlogNum,
        "writerCollect":writerCollect,
        "writerComment":writerComment,
        "writerFan":writerFan,
        "writerGrade":writerGrade,
        "writerIntegral":writerIntegral,
        "writerName":writerName,
        "writerProfileAdress":str("writer_image"+"\\"+writerimagename),
        "writerRankTotal":writerRankTotal,
        "writerRankWeekly":writerRankWeekly,
        "writerThumb":writerThumb,
        "writerVisitNum":writerVisitNum,
        "blog_read_count":blog_read_count,
        "blog_time":blog_time,
        "blog_title":blog_title,
        "content":string_tmp
    }
    
    with open(str("blog_json"+"\\"+blogid+'.json'),"w", encoding = "utf-8") as fjson:
        json.dump(data,fjson,ensure_ascii = False)
    
    #tmp=json.dumps(data,ensure_ascii = False)
    #stringtmp=json.loads(tmp)["content"]

    #with open(str("blog_json"+"\\"+blogid+'.html'),"w", encoding = "utf-8") as fjson:
    #    fjson.write(string_tmp)

# %%
dealWebsite("https://blog.csdn.net/weixin_43786756/article/details/113827284")

# %%
num=0
import time
with open("try.txt","r") as lines:
    for line in lines:
        num+=1
        if(num>7894):
            line=line[:-1]
            #print(ord(line[-1]))
            dealWebsite(line)
            print("now already finished: ",num)
            #print(line)
            time.sleep(0.5)
# Out:
# now already finished:  7895
# now already finished:  7896
# now already finished:  7897
# now already finished:  7898
# now already finished:  7899
# now already finished:  7900
# now already finished:  7901
# now already finished:  7902
# now already finished:  7903
# now already finished:  7904
# now already finished:  7905
# now already finished:  7906
# now already finished:  7907
# now already finished:  7908
# now already finished:  7909
# now already finished:  7910
# now already finished:  7911
# now already finished:  7912
# now already finished:  7913
# now already finished:  7914
# now already finished:  7915
# now already finished:  7916
# now already finished:  7917
# now already finished:  7918
# now already finished:  7919
# now already finished:  7920
# now already finished:  7921
# now already finished:  7922
# now already finished:  7923
# now already finished:  7924
# now already finished:  7925
# now already finished:  7926
# now already finished:  7927
# now already finished:  7928
# now already finished:  7929
# now already finished:  7930
# now already finished:  7931
# now already finished:  7932
# now already finished:  7933
# now already finished:  7934
# now already finished:  7935
# now already finished:  7936
# now already finished:  7937
# now already finished:  7938
# now already finished:  7939
# now already finished:  7940
# now already finished:  7941
# now already finished:  7942
# now already finished:  7943
# now already finished:  7944
# now already finished:  7945
# now already finished:  7946
# now already finished:  7947
# now already finished:  7948
# now already finished:  7949
# now already finished:  7950
# now already finished:  7951
# now already finished:  7952
# now already finished:  7953
# now already finished:  7954
# now already finished:  7955
# now already finished:  7956
# now already finished:  7957
# now already finished:  7958
# now already finished:  7959
# now already finished:  7960
# now already finished:  7961
# now already finished:  7962
# now already finished:  7963
# now already finished:  7964
# now already finished:  7965
# now already finished:  7966
# now already finished:  7967
# now already finished:  7968
# now already finished:  7969
# now already finished:  7970
# now already finished:  7971
# now already finished:  7972
# now already finished:  7973
# now already finished:  7974
# now already finished:  7975
# now already finished:  7976
# now already finished:  7977
# now already finished:  7978
# now already finished:  7979
# now already finished:  7980
# now already finished:  7981
# now already finished:  7982
# now already finished:  7983
# now already finished:  7984
# now already finished:  7985
# now already finished:  7986
# now already finished:  7987
# now already finished:  7988
# now already finished:  7989
# now already finished:  7990
# now already finished:  7991
# now already finished:  7992
# now already finished:  7993
# now already finished:  7994
# now already finished:  7995
# now already finished:  7996
# now already finished:  7997
# now already finished:  7998
# now already finished:  7999
# now already finished:  8000
# now already finished:  8001
# now already finished:  8002
# now already finished:  8003
# now already finished:  8004
# now already finished:  8005
# now already finished:  8006
# now already finished:  8007
# now already finished:  8008
# now already finished:  8009
# now already finished:  8010
# now already finished:  8011
# now already finished:  8012
# now already finished:  8013
# now already finished:  8014
# now already finished:  8015
# now already finished:  8016
# now already finished:  8017
# now already finished:  8018
# now already finished:  8019
# now already finished:  8020
# now already finished:  8021
# now already finished:  8022
# now already finished:  8023
# now already finished:  8024
# now already finished:  8025
# now already finished:  8026
# now already finished:  8027
# now already finished:  8028
# now already finished:  8029
# now already finished:  8030
# now already finished:  8031
# now already finished:  8032
# now already finished:  8033
# now already finished:  8034
# now already finished:  8035
# now already finished:  8036
# now already finished:  8037
# now already finished:  8038
# now already finished:  8039
# now already finished:  8040
# now already finished:  8041
# now already finished:  8042
# now already finished:  8043
# now already finished:  8044
# now already finished:  8045
# now already finished:  8046
# now already finished:  8047
# now already finished:  8048
# now already finished:  8049
# now already finished:  8050
# now already finished:  8051
# now already finished:  8052
# now already finished:  8053
# now already finished:  8054
# now already finished:  8055
# now already finished:  8056
# now already finished:  8057
# now already finished:  8058
# now already finished:  8059
# now already finished:  8060
# now already finished:  8061
# now already finished:  8062
# now already finished:  8063
# now already finished:  8064
# now already finished:  8065
# now already finished:  8066
# now already finished:  8067
# now already finished:  8068
# now already finished:  8069
# now already finished:  8070
# now already finished:  8071
# now already finished:  8072
# now already finished:  8073
# now already finished:  8074
# now already finished:  8075
# now already finished:  8076
# now already finished:  8077
# now already finished:  8078
# now already finished:  8079
# now already finished:  8080
# now already finished:  8081
# now already finished:  8082
# now already finished:  8083
# now already finished:  8084
# now already finished:  8085
# now already finished:  8086
# now already finished:  8087
# now already finished:  8088
# now already finished:  8089
# now already finished:  8090
# now already finished:  8091
# now already finished:  8092
# now already finished:  8093
# now already finished:  8094
# now already finished:  8095
# now already finished:  8096
# now already finished:  8097
# now already finished:  8098
# now already finished:  8099
# now already finished:  8100
# now already finished:  8101
# now already finished:  8102
# now already finished:  8103
# now already finished:  8104
# now already finished:  8105
# now already finished:  8106
# now already finished:  8107
# now already finished:  8108
# now already finished:  8109
# now already finished:  8110
# now already finished:  8111
# now already finished:  8112
# now already finished:  8113
# now already finished:  8114
# now already finished:  8115
# now already finished:  8116
# now already finished:  8117
# now already finished:  8118
# now already finished:  8119
# now already finished:  8120
# now already finished:  8121
# now already finished:  8122
# now already finished:  8123
# now already finished:  8124
# now already finished:  8125
# now already finished:  8126
# now already finished:  8127
# now already finished:  8128
# now already finished:  8129
# now already finished:  8130
# now already finished:  8131
# now already finished:  8132
# now already finished:  8133
# now already finished:  8134
# now already finished:  8135
# now already finished:  8136
# now already finished:  8137
# now already finished:  8138
# now already finished:  8139
# now already finished:  8140
# now already finished:  8141
# now already finished:  8142
# now already finished:  8143
# now already finished:  8144
# now already finished:  8145
# now already finished:  8146
# now already finished:  8147
# now already finished:  8148
# now already finished:  8149
# now already finished:  8150
# now already finished:  8151
# now already finished:  8152
# now already finished:  8153
# now already finished:  8154
# now already finished:  8155
# now already finished:  8156
# now already finished:  8157
# now already finished:  8158
# now already finished:  8159
# now already finished:  8160
# now already finished:  8161
# now already finished:  8162
# now already finished:  8163
# now already finished:  8164
# now already finished:  8165
# now already finished:  8166
# now already finished:  8167
# now already finished:  8168
# now already finished:  8169
# now already finished:  8170
# now already finished:  8171
# now already finished:  8172
# now already finished:  8173
# now already finished:  8174
# now already finished:  8175
# now already finished:  8176
# now already finished:  8177
# now already finished:  8178
# now already finished:  8179
# now already finished:  8180
# now already finished:  8181
# now already finished:  8182
# now already finished:  8183
# now already finished:  8184
# now already finished:  8185
# now already finished:  8186
# now already finished:  8187
# now already finished:  8188
# now already finished:  8189
# now already finished:  8190
# now already finished:  8191
# now already finished:  8192
# now already finished:  8193
# now already finished:  8194
# now already finished:  8195
# now already finished:  8196
# now already finished:  8197
# now already finished:  8198
# now already finished:  8199
# now already finished:  8200
# now already finished:  8201
# now already finished:  8202
# now already finished:  8203
# now already finished:  8204
# now already finished:  8205
# now already finished:  8206
# now already finished:  8207
# now already finished:  8208
# now already finished:  8209
# now already finished:  8210
# now already finished:  8211
# now already finished:  8212
# now already finished:  8213
# now already finished:  8214
# now already finished:  8215
# now already finished:  8216
# now already finished:  8217
# now already finished:  8218
# now already finished:  8219
# now already finished:  8220
# now already finished:  8221
# now already finished:  8222
# now already finished:  8223
# now already finished:  8224
# now already finished:  8225
# now already finished:  8226
# now already finished:  8227
# now already finished:  8228
# now already finished:  8229
# now already finished:  8230
# now already finished:  8231
# now already finished:  8232
# now already finished:  8233
# now already finished:  8234
# now already finished:  8235
# now already finished:  8236
# now already finished:  8237
# now already finished:  8238
# now already finished:  8239
# now already finished:  8240
# now already finished:  8241
# now already finished:  8242
# now already finished:  8243
# now already finished:  8244
# now already finished:  8245
# now already finished:  8246
# now already finished:  8247
# now already finished:  8248
# now already finished:  8249
# now already finished:  8250
# now already finished:  8251
# now already finished:  8252
# now already finished:  8253
# now already finished:  8254
# now already finished:  8255
# now already finished:  8256
# now already finished:  8257
# now already finished:  8258
# now already finished:  8259
# now already finished:  8260
# now already finished:  8261
# now already finished:  8262
# now already finished:  8263
# now already finished:  8264
# now already finished:  8265
# now already finished:  8266
# now already finished:  8267
# now already finished:  8268
# now already finished:  8269
# now already finished:  8270
# now already finished:  8271
# now already finished:  8272
# now already finished:  8273
# now already finished:  8274
# now already finished:  8275
# now already finished:  8276
# now already finished:  8277
# now already finished:  8278
# now already finished:  8279
# now already finished:  8280
# now already finished:  8281
# now already finished:  8282
# now already finished:  8283
# now already finished:  8284
# now already finished:  8285
# now already finished:  8286
# now already finished:  8287
# now already finished:  8288
# now already finished:  8289
# now already finished:  8290
# now already finished:  8291
# now already finished:  8292
# now already finished:  8293
# now already finished:  8294
# now already finished:  8295
# now already finished:  8296
# now already finished:  8297
# now already finished:  8298
# now already finished:  8299
# now already finished:  8300
# now already finished:  8301
# now already finished:  8302
# now already finished:  8303
# now already finished:  8304
# now already finished:  8305
# now already finished:  8306
# now already finished:  8307
# now already finished:  8308
# now already finished:  8309
# now already finished:  8310
# now already finished:  8311
# now already finished:  8312
# now already finished:  8313
# now already finished:  8314
# now already finished:  8315
# now already finished:  8316
# now already finished:  8317
# now already finished:  8318
# now already finished:  8319
# now already finished:  8320
# now already finished:  8321
# now already finished:  8322
# now already finished:  8323
# now already finished:  8324
# now already finished:  8325
# now already finished:  8326
# now already finished:  8327
# now already finished:  8328
# now already finished:  8329
# now already finished:  8330
# now already finished:  8331
# now already finished:  8332
# now already finished:  8333
# now already finished:  8334
# now already finished:  8335
# now already finished:  8336
# now already finished:  8337
# now already finished:  8338
# now already finished:  8339
# now already finished:  8340
# now already finished:  8341
# now already finished:  8342
# now already finished:  8343
# now already finished:  8344
# now already finished:  8345
# now already finished:  8346
# now already finished:  8347
# now already finished:  8348
# now already finished:  8349
# now already finished:  8350
# now already finished:  8351
# now already finished:  8352
# now already finished:  8353
# now already finished:  8354
# now already finished:  8355
# now already finished:  8356
# now already finished:  8357
# now already finished:  8358
# now already finished:  8359
# now already finished:  8360
# now already finished:  8361
# now already finished:  8362
# now already finished:  8363
# now already finished:  8364
# now already finished:  8365
# now already finished:  8366
# now already finished:  8367
# now already finished:  8368
# now already finished:  8369
# now already finished:  8370
# now already finished:  8371
# now already finished:  8372
# now already finished:  8373
# now already finished:  8374
# now already finished:  8375
# now already finished:  8376
# now already finished:  8377
# now already finished:  8378
# now already finished:  8379
# now already finished:  8380
# now already finished:  8381
# now already finished:  8382
# now already finished:  8383
# now already finished:  8384
# now already finished:  8385
# now already finished:  8386
# now already finished:  8387
# now already finished:  8388
# now already finished:  8389
# now already finished:  8390
# now already finished:  8391
# now already finished:  8392
# now already finished:  8393
# now already finished:  8394
# now already finished:  8395
# now already finished:  8396
# now already finished:  8397
# now already finished:  8398
# now already finished:  8399
# now already finished:  8400
# now already finished:  8401
# now already finished:  8402
# now already finished:  8403
# now already finished:  8404
# now already finished:  8405
# now already finished:  8406
# now already finished:  8407
# now already finished:  8408
# now already finished:  8409
# now already finished:  8410
# now already finished:  8411
# now already finished:  8412
# now already finished:  8413
# now already finished:  8414
# now already finished:  8415
# now already finished:  8416
# now already finished:  8417
# now already finished:  8418
# now already finished:  8419
# now already finished:  8420
# now already finished:  8421
# now already finished:  8422
# now already finished:  8423
# now already finished:  8424
# now already finished:  8425
# now already finished:  8426
# now already finished:  8427
# now already finished:  8428
# now already finished:  8429
# now already finished:  8430
# now already finished:  8431
# now already finished:  8432
# now already finished:  8433
# now already finished:  8434
# now already finished:  8435
# now already finished:  8436
# now already finished:  8437
# now already finished:  8438
# now already finished:  8439
# now already finished:  8440
# now already finished:  8441
# now already finished:  8442
# now already finished:  8443
# now already finished:  8444
# now already finished:  8445
# now already finished:  8446
# now already finished:  8447
# now already finished:  8448
# now already finished:  8449
# now already finished:  8450
# now already finished:  8451
# now already finished:  8452
# now already finished:  8453
# now already finished:  8454
# now already finished:  8455
# now already finished:  8456
# now already finished:  8457
# now already finished:  8458
# now already finished:  8459
# now already finished:  8460
# now already finished:  8461
# now already finished:  8462
# now already finished:  8463
# now already finished:  8464
# now already finished:  8465
# now already finished:  8466
# now already finished:  8467
# now already finished:  8468
# now already finished:  8469
# now already finished:  8470
# now already finished:  8471
# now already finished:  8472
# now already finished:  8473
# now already finished:  8474
# now already finished:  8475
# now already finished:  8476
# now already finished:  8477
# now already finished:  8478
# now already finished:  8479
# now already finished:  8480
# now already finished:  8481
# now already finished:  8482
# now already finished:  8483
# now already finished:  8484
# now already finished:  8485
# now already finished:  8486
# now already finished:  8487
# now already finished:  8488
# now already finished:  8489
# now already finished:  8490
# now already finished:  8491
# now already finished:  8492
# now already finished:  8493
# now already finished:  8494
# now already finished:  8495
# now already finished:  8496
# now already finished:  8497
# now already finished:  8498
# now already finished:  8499
# now already finished:  8500
# now already finished:  8501
# now already finished:  8502
# now already finished:  8503
# now already finished:  8504
# now already finished:  8505
# now already finished:  8506
# now already finished:  8507
# now already finished:  8508
# now already finished:  8509
# now already finished:  8510
# now already finished:  8511
# now already finished:  8512
# now already finished:  8513
# now already finished:  8514
# now already finished:  8515
# now already finished:  8516
# now already finished:  8517
# now already finished:  8518
# now already finished:  8519
# now already finished:  8520
# now already finished:  8521
# now already finished:  8522
# now already finished:  8523
# now already finished:  8524
# now already finished:  8525
# now already finished:  8526
# now already finished:  8527
# now already finished:  8528
# now already finished:  8529
# now already finished:  8530
# now already finished:  8531
# now already finished:  8532
# now already finished:  8533
# now already finished:  8534
# now already finished:  8535
# now already finished:  8536
# now already finished:  8537
# now already finished:  8538
# now already finished:  8539
# now already finished:  8540
# now already finished:  8541
# now already finished:  8542
# now already finished:  8543
# now already finished:  8544
# now already finished:  8545
# now already finished:  8546
# now already finished:  8547
# now already finished:  8548
# now already finished:  8549
# now already finished:  8550
# now already finished:  8551
# now already finished:  8552
# now already finished:  8553
# now already finished:  8554
# now already finished:  8555
# now already finished:  8556
# now already finished:  8557
# now already finished:  8558
# now already finished:  8559
# now already finished:  8560
# now already finished:  8561
# now already finished:  8562
# now already finished:  8563
# now already finished:  8564
# now already finished:  8565
# now already finished:  8566
# now already finished:  8567
# now already finished:  8568
# now already finished:  8569
# now already finished:  8570
# now already finished:  8571
# now already finished:  8572
# now already finished:  8573
# now already finished:  8574
# now already finished:  8575
# now already finished:  8576
# now already finished:  8577
# now already finished:  8578
# now already finished:  8579
# now already finished:  8580
# now already finished:  8581
# now already finished:  8582
# now already finished:  8583
# now already finished:  8584
# now already finished:  8585
# now already finished:  8586
# now already finished:  8587
# now already finished:  8588
# now already finished:  8589
# now already finished:  8590
# now already finished:  8591
# now already finished:  8592
# now already finished:  8593
# now already finished:  8594
# now already finished:  8595
# now already finished:  8596
# now already finished:  8597
# now already finished:  8598
# now already finished:  8599
# now already finished:  8600
# now already finished:  8601
# now already finished:  8602
# now already finished:  8603
# now already finished:  8604
# now already finished:  8605
# now already finished:  8606
# now already finished:  8607
# now already finished:  8608
# now already finished:  8609
# now already finished:  8610
# now already finished:  8611
# now already finished:  8612
# now already finished:  8613
# now already finished:  8614
# now already finished:  8615
# now already finished:  8616
# now already finished:  8617
# now already finished:  8618
# now already finished:  8619
# now already finished:  8620
# now already finished:  8621
# now already finished:  8622
# now already finished:  8623
# now already finished:  8624
# now already finished:  8625
# now already finished:  8626
# now already finished:  8627
# now already finished:  8628
# now already finished:  8629
# now already finished:  8630
# now already finished:  8631
# now already finished:  8632
# now already finished:  8633
# now already finished:  8634
# now already finished:  8635
# now already finished:  8636
# now already finished:  8637
# now already finished:  8638
# now already finished:  8639
# now already finished:  8640
# now already finished:  8641
# now already finished:  8642
# now already finished:  8643
# now already finished:  8644
# now already finished:  8645
# now already finished:  8646
# now already finished:  8647
# now already finished:  8648
# now already finished:  8649
# now already finished:  8650
# now already finished:  8651
# now already finished:  8652
# now already finished:  8653
# now already finished:  8654
# now already finished:  8655
# now already finished:  8656
# now already finished:  8657
# now already finished:  8658
# now already finished:  8659
# now already finished:  8660
# now already finished:  8661
# now already finished:  8662
# now already finished:  8663
# now already finished:  8664
# now already finished:  8665
# now already finished:  8666
# now already finished:  8667
# now already finished:  8668
# now already finished:  8669
# now already finished:  8670
# now already finished:  8671
# now already finished:  8672
# now already finished:  8673
# now already finished:  8674
# now already finished:  8675
# now already finished:  8676
# now already finished:  8677
# now already finished:  8678
# now already finished:  8679
# now already finished:  8680
# now already finished:  8681
# now already finished:  8682
# now already finished:  8683
# now already finished:  8684
# now already finished:  8685
# now already finished:  8686
# now already finished:  8687
# now already finished:  8688
# now already finished:  8689
# now already finished:  8690
# now already finished:  8691
# now already finished:  8692
# now already finished:  8693
# now already finished:  8694
# now already finished:  8695
# now already finished:  8696
# now already finished:  8697
# now already finished:  8698
# now already finished:  8699
# now already finished:  8700
# now already finished:  8701
# now already finished:  8702
# now already finished:  8703
# now already finished:  8704
# now already finished:  8705
# now already finished:  8706
# now already finished:  8707
# now already finished:  8708
# now already finished:  8709
# now already finished:  8710
# now already finished:  8711
# now already finished:  8712
# now already finished:  8713
# now already finished:  8714
# now already finished:  8715
# now already finished:  8716
# now already finished:  8717
# now already finished:  8718
# now already finished:  8719
# now already finished:  8720
# now already finished:  8721
# now already finished:  8722
# now already finished:  8723
# now already finished:  8724
# now already finished:  8725
# now already finished:  8726
# now already finished:  8727
# now already finished:  8728
# now already finished:  8729
# now already finished:  8730
# now already finished:  8731
# now already finished:  8732
# now already finished:  8733
# now already finished:  8734
# now already finished:  8735
# now already finished:  8736
# now already finished:  8737
# now already finished:  8738
# now already finished:  8739
# now already finished:  8740
# now already finished:  8741
# now already finished:  8742
# now already finished:  8743
# now already finished:  8744
# now already finished:  8745
# now already finished:  8746
# now already finished:  8747
# now already finished:  8748
# now already finished:  8749
# now already finished:  8750
# now already finished:  8751
# now already finished:  8752
# now already finished:  8753
# now already finished:  8754
# now already finished:  8755
# now already finished:  8756
# now already finished:  8757
# now already finished:  8758
# now already finished:  8759
# now already finished:  8760
# now already finished:  8761
# now already finished:  8762
# now already finished:  8763
# now already finished:  8764
# now already finished:  8765
# now already finished:  8766
# now already finished:  8767
# now already finished:  8768
# now already finished:  8769
# now already finished:  8770
# now already finished:  8771
# now already finished:  8772
# now already finished:  8773
# now already finished:  8774
# now already finished:  8775
# now already finished:  8776
# now already finished:  8777
# now already finished:  8778
# now already finished:  8779
# now already finished:  8780
# now already finished:  8781
# now already finished:  8782
# now already finished:  8783
# now already finished:  8784
# now already finished:  8785
# now already finished:  8786
# now already finished:  8787
# now already finished:  8788
# now already finished:  8789
# now already finished:  8790
# now already finished:  8791
# now already finished:  8792
# now already finished:  8793
# now already finished:  8794
# now already finished:  8795
# now already finished:  8796
# now already finished:  8797
# now already finished:  8798
# now already finished:  8799
# now already finished:  8800
# now already finished:  8801
# now already finished:  8802
# now already finished:  8803
# now already finished:  8804
# now already finished:  8805
# now already finished:  8806
# now already finished:  8807
# now already finished:  8808
# now already finished:  8809
# now already finished:  8810
# now already finished:  8811
# now already finished:  8812
# now already finished:  8813
# now already finished:  8814
# now already finished:  8815
# now already finished:  8816
# now already finished:  8817
# now already finished:  8818
# now already finished:  8819
# now already finished:  8820
# now already finished:  8821
# now already finished:  8822
# now already finished:  8823
# now already finished:  8824
# now already finished:  8825
# now already finished:  8826
# now already finished:  8827
# now already finished:  8828
# now already finished:  8829
# now already finished:  8830
# now already finished:  8831
# now already finished:  8832
# now already finished:  8833
# now already finished:  8834
# now already finished:  8835
# now already finished:  8836
# now already finished:  8837
# now already finished:  8838
# now already finished:  8839
# now already finished:  8840
# now already finished:  8841
# now already finished:  8842
# now already finished:  8843
# now already finished:  8844
# now already finished:  8845
# now already finished:  8846
# now already finished:  8847
# now already finished:  8848
# now already finished:  8849
# now already finished:  8850
# now already finished:  8851
# now already finished:  8852
# now already finished:  8853
# now already finished:  8854
# now already finished:  8855
# now already finished:  8856
# now already finished:  8857
# now already finished:  8858
# now already finished:  8859
# now already finished:  8860
# now already finished:  8861
# now already finished:  8862
# now already finished:  8863
# now already finished:  8864
# now already finished:  8865
# now already finished:  8866
# now already finished:  8867
# now already finished:  8868
# now already finished:  8869
# now already finished:  8870
# now already finished:  8871
# now already finished:  8872
# now already finished:  8873
# now already finished:  8874
# now already finished:  8875
# now already finished:  8876
# now already finished:  8877
# now already finished:  8878
# now already finished:  8879
# now already finished:  8880
# now already finished:  8881
# now already finished:  8882
# now already finished:  8883
# now already finished:  8884
# now already finished:  8885
# now already finished:  8886
# now already finished:  8887
# now already finished:  8888
# now already finished:  8889
# now already finished:  8890
# now already finished:  8891
# now already finished:  8892
# now already finished:  8893
# now already finished:  8894
# now already finished:  8895
# now already finished:  8896
# now already finished:  8897
# now already finished:  8898
# now already finished:  8899
# now already finished:  8900
# now already finished:  8901
# now already finished:  8902
# now already finished:  8903
# now already finished:  8904
# now already finished:  8905
# now already finished:  8906
# now already finished:  8907
# now already finished:  8908
# now already finished:  8909
# now already finished:  8910
# now already finished:  8911
# now already finished:  8912
# now already finished:  8913
# now already finished:  8914
# now already finished:  8915
# now already finished:  8916
# now already finished:  8917
# now already finished:  8918
# now already finished:  8919
# now already finished:  8920
# now already finished:  8921
# now already finished:  8922
# now already finished:  8923
# now already finished:  8924
# now already finished:  8925
# now already finished:  8926
# now already finished:  8927
# now already finished:  8928
# now already finished:  8929
# now already finished:  8930
# now already finished:  8931
# now already finished:  8932
# now already finished:  8933
# now already finished:  8934
# now already finished:  8935
# now already finished:  8936
# now already finished:  8937
# now already finished:  8938
# now already finished:  8939
# now already finished:  8940
# now already finished:  8941
# now already finished:  8942
# now already finished:  8943
# now already finished:  8944
# now already finished:  8945
# now already finished:  8946
# now already finished:  8947
# now already finished:  8948
# now already finished:  8949
# now already finished:  8950
# now already finished:  8951
# now already finished:  8952
# now already finished:  8953
# now already finished:  8954
# now already finished:  8955
# now already finished:  8956
# now already finished:  8957
# now already finished:  8958
# now already finished:  8959
# now already finished:  8960
# now already finished:  8961
# now already finished:  8962
# now already finished:  8963
# now already finished:  8964
# now already finished:  8965
# now already finished:  8966
# now already finished:  8967
# now already finished:  8968
# now already finished:  8969
# now already finished:  8970
# now already finished:  8971
# now already finished:  8972
# now already finished:  8973
# now already finished:  8974
# now already finished:  8975
# now already finished:  8976
# now already finished:  8977
# now already finished:  8978
# now already finished:  8979
# now already finished:  8980
# now already finished:  8981
# now already finished:  8982
# now already finished:  8983
# now already finished:  8984
# now already finished:  8985
# now already finished:  8986
# now already finished:  8987
# now already finished:  8988
# now already finished:  8989
# now already finished:  8990
# now already finished:  8991
# now already finished:  8992
# now already finished:  8993
# now already finished:  8994
# now already finished:  8995
# now already finished:  8996
# now already finished:  8997
# now already finished:  8998
# now already finished:  8999
# now already finished:  9000
# now already finished:  9001
# now already finished:  9002
# now already finished:  9003
# now already finished:  9004
# now already finished:  9005
# now already finished:  9006
# now already finished:  9007
# now already finished:  9008
# now already finished:  9009
# now already finished:  9010
# now already finished:  9011
# now already finished:  9012
# now already finished:  9013
# now already finished:  9014
# now already finished:  9015
# now already finished:  9016
# now already finished:  9017
# now already finished:  9018
# now already finished:  9019
# now already finished:  9020
# now already finished:  9021
# now already finished:  9022
# now already finished:  9023
# now already finished:  9024
# now already finished:  9025
# now already finished:  9026

# %%
dealWebsite("https://blog.csdn.net/weixin_54696666/article/details/126603219")
# Out:
# https://blog.csdn.net/weixin_54696666/article/details/126603219
# <Response [200]>

# %%
blogid="126255974"
loadingf=open("126255974.json",'r',encoding = "utf-8")
data=json.load(loadingf)
data=data["content"]
loadingf.close()

#tmp=json.dumps(data,ensure_ascii = False)
#stringtmp=json.loads(tmp)["content"]
#data
with open(str(blogid+'.html'),"w", encoding = "utf-8") as fjson:
    fjson.write(data)

# %%
import json

with open("try.txt","r") as lines:
    for line in lines:
        blogid=line.split('/')[-1][:-1]
        try:
            loadingf=open(str("blog_json\\"+blogid+".json"),'r',encoding='utf-8')
            data=json.load(loadingf)
            data=data["content"]
            loadingf.close
            with open(str("content_html\\"+blogid+".html"),"w",encoding="utf-8") as fbloghtml:
                fbloghtml.write(data)
        except:
            continue

# %%
import json
import datetime
from blog.models import BlogInfo

with open("..\\Python\\quchong.txt","r") as lines:
    point = list([])
    for line in lines:
        blogid1=line.split('/')[-1][:-1]
        if(int(blogid1) in point == True):
            print("11111111111111111111111111111111111111111")
            continue
        else:
            point.append(int(blogid1))
            try:
                loadingf=open(str("..\\Python\\new_blog_json\\"+blogid1+".json"),'r',encoding='utf-8')
                data=json.load(loadingf)
                loadingf.close
                print(data['blogid'])
                try:
                    BlogInfo.objects.create(blogid=data['blogid'],
                                            writerAge=data['writerAge'],
                                            writerBlogNum=data['writerBlogNum'],
                                            writerCollect=data['writerCollect'],
                                            writerComment=data['writerComment'],
                                            writerFan=data['writerFan'],
                                            writerGrade=data['writerGrade'],
                                            writerIntegral=data['writerIntegral'],
                                            writerName=data['writerName'],
                                            writerRankWeekly=data['writerRankWeekly'],
                                            writerRankTotal=data['writerRankTotal'],
                                            writerProfileAdress=data['writerProfileAdress'],
                                            writerThumb=data['writerThumb'],
                                            writerVisitNum=data['writerVisitNum'],
                                            blog_read_count=data['blog_read_count'],
                                            blog_time=data['blog_time'],
                                            blog_title=data['blog_title'],
                                            content=data['content'],
                                            cpp=data['cpp'],
                                            csharp=data['csharp'],
                                            java=data['java'],
                                            javascript=data['javascript'],
                                            php=data['php'],
                                            sqll=data['sql'],
                                            python=data['python'],
                                            first_tag=data['first_tag']
                                            ,summa=data["summary"][:50],
                                            time=data["time"]
                                            )
                except:
                    print("Error!")
            except:
                continue
lines.close()

# %%
import json
import re
from turtle import title
import datetime

with open("quchong.txt","r") as lines:
    for line in lines:
        blogid=line.split('/')[-1][:-1]
        try:
            loadingf=open(str("blog_json\\"+blogid+".json"),'r',encoding='utf-8')
            data=json.load(loadingf)
            aaa=data["content"]
            aaa=aaa.replace("image\\","..\\..\\static\\image\\")
            #aaa=aaa.replace("writer_image\\","..\\..\\static\\writer_image\\")
            aaa=aaa.replace("href=\"style.css\"","href=\"../../static/bootstrap/css/csdnstyle.css\"")
            #print(aaa)
            data["content"]=aaa

            aaa=data["writerProfileAdress"]
            aaa=aaa.replace("writer_image\\","..\\..\\static\\writer_image\\")
            data["writerProfileAdress"]=aaa

            data["first_tag"]="Others"

            pipei=re.compile(r'C\+\+',re.IGNORECASE)
            if (re.search(pipei,data["content"])==None and re.search(pipei,data["blog_title"])==None):
                data["cpp"]=0
            else:
                data["cpp"]=1
                data["first_tag"]="C++"

            pipei=re.compile(r'C#',re.IGNORECASE)
            if (re.search(pipei,data["content"])==None and re.search(pipei,data["blog_title"])==None):
                data["csharp"]=0
            else:
                data["csharp"]=1
                data["first_tag"]="C#"
            
            pipei=re.compile(r'Python',re.IGNORECASE)
            if (re.search(pipei,data["content"])==None and re.search(pipei,data["blog_title"])==None):
                data["python"]=0
            else:
                data["python"]=1
                data["first_tag"]="Python"

            pipei=re.compile(r'JavaScript',re.IGNORECASE)
            if (re.search(pipei,data["content"])==None and re.search(pipei,data["blog_title"])==None):
                data["javascript"]=0
            else:
                data["javascript"]=1
                data["first_tag"]="JavaScript"

            pipei=re.compile(r'java',re.IGNORECASE)
            if (re.search(pipei,data["content"])==None and re.search(pipei,data["blog_title"])==None):
                data["java"]=0
            elif data["javascript"] == 0 :
                data["java"]=1    
                data["first_tag"]="Java" 
            else:
                data["java"]=0   

            pipei=re.compile(r'SQL',re.IGNORECASE)
            if (re.search(pipei,data["content"])==None and re.search(pipei,data["blog_title"])==None):
                data["sql"]=0
            else:
                data["sql"]=1        
                data["first_tag"]="SQL"

            pipei=re.compile(r'PHP',re.IGNORECASE)
            if (re.search(pipei,data["content"])==None and re.search(pipei,data["blog_title"])==None):
                data["php"]=0
            else:
                data["php"]=1
                data["first_tag"]="PHP"
                
            re_time=re.compile('[1-9]\d{3}-(0[1-9]|1[0-2])-(0[1-9]|[1-2][0-9]|3[0-1])\s+(20|21|22|23|[0-1]\d):[0-5]\d:[0-5]\d')
            thistime=re_time.search(data["blog_time"]).group()  
            data['time']=thistime

            re_ch=re.compile(u'[\u4e00-\u9fa5\，\。\！\？\、\；\》\《\：]')
            stringzh=data["content"][:5000]
            zhresult=re.findall(re_ch,stringzh)
            zhresult=''.join(zhresult)[:100]
            data['summary']=zhresult

            with open(str("new_blog_json\\"+blogid+".json"),"w",encoding="utf-8") as fbloghtml:
                json.dump(data,fbloghtml,ensure_ascii = False)
        
        except:
            print("error!")
            continue
        #break
# Out:
# error!
# error!
# error!

# %%
import re

string="djkashfkahcksj dalsruoadfdjk  csdfhakasfashfawdkashd c++ sidaosdhhjafhaskfhsjfdhksafhkasc"
pipei=re.compile(r"C\+\+",re.IGNORECASE)
dddsss={}
if (pipei.search(string)==None):
    dddsss["cpp"]=0
else:
    dddsss["cpp"]=1

dddsss
# Out:
# {'cpp': 1}

# %%
aaaaaaa=['dsfs']
aaaaaaa.append(str('sdsa'))
aaaaaaa+='eiwur'
aaaaaaa
# Out:
# ['dsfs', 'sdsa', 'e', 'i', 'w', 'u', 'r']
